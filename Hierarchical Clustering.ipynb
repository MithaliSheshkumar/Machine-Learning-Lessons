# %% [markdown]
# # **Lesson: Hierarchical Clustering**

# %% [raw]
# Hierarchical clustering is another unsupervised machine learning algorithm used for grouping data points into clusters. Unlike K-Means, it does not require you to specify the number of clusters (K) upfront and builds a hierarchy of clusters instead.

# %% [markdown]
# ## **Types of Hierarchical Clustering**

# %% [raw]
# 1. **Agglomerative (Bottom-Up Approach) → Most Common**
#    - Starts with each data point as its own cluster.
#    - Merges the closest clusters step by step until only one remains.

# %% [raw]
# 2. **Divisive (Top-Down Approach)**
#    - Starts with all points in a single cluster.
#    - Splits them iteratively into smaller clusters.

# %% [markdown]
# ## **Key Concepts in Hierarchical Clustering**

# %% [markdown]
# ### **1. Distance Metrics**

# %% [raw]
# To decide which clusters should merge, we measure the **distance** between them using:
# - **Euclidean Distance**: Commonly used, measures straight-line distance.
# - **Manhattan Distance**: Measures absolute differences.

# %% [markdown]
# ### **2. Linkage Methods**

# %% [raw]
# Determines how distances between clusters are calculated:
# - **Single Linkage**: Distance between the closest points in two clusters.
# - **Complete Linkage**: Distance between the farthest points in two clusters.
# - **Average Linkage**: Average of all pairwise distances between two clusters.
# - **Ward’s Method**: Minimizes variance within clusters (preferred in most cases).

# %% [markdown]
# ## **Steps in Agglomerative Hierarchical Clustering**

# %% [raw]
# 1. **Treat each data point as an individual cluster.**
# 2. **Calculate distance between clusters.**
# 3. **Merge the closest clusters.**
# 4. **Repeat until all points are in one large cluster.**
# 5. **Use a dendrogram to visualize and determine the optimal number of clusters.**

# %% [markdown]
# ## **Python Implementation of Hierarchical Clustering**
# Let's apply hierarchical clustering on a dataset.

# %%
### **Example 1: Customer Segmentation (Annual Income vs Spending Score)**
#```python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler

# Sample data: Customer Income vs Spending Score
data = {'Annual_Income': [15, 16, 17, 35, 45, 55, 85, 95, 75, 65],
        'Spending_Score': [39, 81, 6, 50, 42, 79, 12, 66, 85, 90]}
df = pd.DataFrame(data)

# Normalize data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# Create a Dendrogram to determine optimal clusters
plt.figure(figsize=(8, 5))
dendrogram = sch.dendrogram(sch.linkage(df_scaled, method='ward'))
plt.title("Dendrogram for Hierarchical Clustering")
plt.xlabel("Data Points")
plt.ylabel("Euclidean Distance")
plt.show()

# Applying Agglomerative Clustering with 3 clusters (based on dendrogram)
hc = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
df['Cluster'] = hc.fit_predict(df_scaled)

# Visualizing the clusters
plt.scatter(df['Annual_Income'], df['Spending_Score'], c=df['Cluster'], cmap='viridis')
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.title("Customer Clusters (Hierarchical Clustering)")
plt.show()
#```
# Out:
# Matplotlib is building the font cache; this may take a moment.
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sklearn/cluster/_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %% [markdown]
# ## **Real-Life Applications of Hierarchical Clustering**

# %% [raw]
# 1. **Customer Segmentation**
#    - Grouping customers based on spending patterns for targeted marketing.
# 2. **Gene Analysis in Biology**
#    - Used to identify genetic similarities among species.
# 3. **Anomaly Detection**
#    - Finding fraud in financial transactions.
# 4. **Document or Text Clustering**
#    - Categorizing news articles based on topics.

# %% [markdown]
# ## **Advantages vs. Disadvantages of Hierarchical Clustering**

# %% [markdown]
# | **Pros** | **Cons** |
# |----------|---------|
# | No need to specify K upfront | Computationally expensive for large datasets |
# | Dendrogram helps visualize clusters | Sensitive to noise/outliers |
# | Works well for hierarchical data | Hard to scale beyond a few thousand data points |

# %% [markdown]
# ## **Comparison: K-Means vs. Hierarchical Clustering**

# %% [markdown]
# | Feature | K-Means | Hierarchical Clustering |
# |---------|--------|-------------------------|
# | **Need to specify K?** | Yes | No |
# | **Works well for large datasets?** | Yes | No |
# | **Cluster Shape** | Spherical | Can capture complex shapes |
# | **Performance** | Faster | Slower |
# | **Visualization** | Harder | Uses Dendrogram |

# %% [markdown]
# ## **Conclusion**

# %% [raw]
# - Hierarchical clustering is useful when you **don’t know the number of clusters** in advance.
# - The **dendrogram helps** decide how many clusters to use.
# - **Agglomerative clustering** (bottom-up) is the most common approach.
# - For **big datasets, K-Means is usually faster**, but hierarchical clustering provides more insight.
